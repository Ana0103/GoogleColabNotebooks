# %% [markdown]
# <a href="https://colab.research.google.com/github/vidit0210/GoogleColabNotebooks/blob/master/Predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-8f22e068-800c-4d34-93f9-bb394e8cf4c2" name="files[]" multiple disabled />
#      <output id="result-8f22e068-800c-4d34-93f9-bb394e8cf4c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data.csv to Data.csv
# User uploaded file "Data.csv" with length 135322 bytes

# %%
  
dataframe = pd.read_csv("Data.csv",sep='\t')
dataframe.head()
# Out:
#    Unnamed: 0  S0    S1    S2    S3  label
# 0           0   1  0.51  0.36  0.13  -0.02
# 1           1   1  0.31  0.10  0.59   0.38
# 2           2   1  0.27  0.15  0.58   0.46
# 3           3   1  0.36  0.21  0.43   0.28
# 4           4   1  0.70  0.57 -0.27  -0.40

# %%
df_label = dataframe['label']
df_features = dataframe.drop(['label','Unnamed: 0'], 1)
print(df_label.head())
df_features.head()
# Out:
# 0   -0.02
# 1    0.38
# 2    0.46
# 3    0.28
# 4   -0.40
# Name: label, dtype: float64
#    S0    S1    S2    S3
# 0   1  0.51  0.36  0.13
# 1   1  0.31  0.10  0.59
# 2   1  0.27  0.15  0.58
# 3   1  0.36  0.21  0.43
# 4   1  0.70  0.57 -0.27

# %%
data = np.array(df_features)
label = np.array(df_label)
print(data.shape,label.shape)
# Out:
# (5000, 4) (5000,)

# %%
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=42)
x_train.shape
# Out:
# (4000, 4)

# %%
def build_regressor():
    regressor = Sequential()
    regressor.add(Dense(units=500, input_dim=4))
    regressor.add(Dense(units=100))
    regressor.add(Dense(units=50))
    regressor.add(Dense(units=1))
    regressor.compile(optimizer='SGD', loss='mean_squared_error',  metrics=['mae','accuracy'])
    return regressor

# %%
from keras.wrappers.scikit_learn import KerasRegressor
regressor = KerasRegressor(build_fn=build_regressor, batch_size=32,epochs=500)

# %%
results=regressor.fit(x_train,y_train)
# Out:
# Epoch 1/500
# 4000/4000 [==============================] - 0s 121us/step - loss: 0.0286 - mean_absolute_error: 0.1196 - acc: 0.0173
# Epoch 2/500
# 4000/4000 [==============================] - 0s 70us/step - loss: 0.0039 - mean_absolute_error: 0.0478 - acc: 0.0177
# Epoch 3/500
# 4000/4000 [==============================] - 0s 79us/step - loss: 8.8658e-04 - mean_absolute_error: 0.0228 - acc: 0.0177
# Epoch 4/500
# 4000/4000 [==============================] - 0s 70us/step - loss: 1.8314e-04 - mean_absolute_error: 0.0103 - acc: 0.0177
# Epoch 5/500
# 4000/4000 [==============================] - 0s 69us/step - loss: 3.5627e-05 - mean_absolute_error: 0.0045 - acc: 0.0177
# Epoch 6/500
# 4000/4000 [==============================] - 0s 70us/step - loss: 6.7640e-06 - mean_absolute_error: 0.0020 - acc: 0.0177
# Epoch 7/500
# 4000/4000 [==============================] - 0s 64us/step - loss: 1.2640e-06 - mean_absolute_error: 8.5472e-04 - acc: 0.0177
# Epoch 8/500
# ...

# %%
y_pred= regressor.predict(x_test)

# %%
print(y_pred)
# Out:
# [-3.60000014e-01 -6.19999886e-01 -3.99999559e-01  7.99999952e-01
#   4.00001928e-02  8.19999933e-01 -5.40000260e-01  3.20000023e-01
#   4.99999911e-01  5.40000021e-01 -3.80000085e-01 -5.40000021e-01
#   9.39999819e-01 -8.80000055e-01 -5.39999843e-01  1.99999690e-01
#   3.00000131e-01  2.00000294e-02 -3.39999646e-01  4.19999868e-01
#   6.80000007e-01  7.40000010e-01 -3.39999825e-01  8.19999933e-01
#  -7.40000427e-01 -8.99999499e-01  2.79999852e-01  1.99999027e-02
#   9.79999900e-01  9.59999919e-01  2.59999961e-01 -2.39999741e-01
#  -2.00000018e-01 -9.60000217e-01 -3.59999895e-01 -8.00000310e-01
#  -1.39999956e-01 -5.79999864e-01 -6.59999907e-01 -8.20000172e-01
#   3.19999993e-01  2.99999982e-01  2.79999852e-01 -9.39999759e-01
#  -2.00000405e-01  8.19999993e-01 -4.59999889e-01 -9.00000095e-01
#   3.40000182e-01  3.40000004e-01 -8.99999976e-01 -8.80000055e-01
#   4.60000157e-01 -6.80000186e-01 -9.59999859e-01  6.99999869e-01
# ...

# %%
feature_try = np.array([x_train[0]])
feature_try2 = np.array([x_train[1]])



result =model.predict_classes(feature_try2)

# %%
print(result)
# Out:
# [[1]]
